# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_apple=pd.read_csv('apple_stock_data.csv')
df_amazon=pd.read_csv('amazon_stock_data.csv')
df_google=pd.read_csv('google_stock_data.csv')

# %%
df_apple.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2023-12-07 00:00:00-05:00  192.686027  194.049343  192.646214  193.322906
# 1  2023-12-08 00:00:00-05:00  193.253227  195.034508  192.725812  194.755875
# 2  2023-12-11 00:00:00-05:00  192.168554  192.546706  190.486791  192.238205
# 3  2023-12-12 00:00:00-05:00  192.138714  193.770718  190.785344  193.760773
# 4  2023-12-13 00:00:00-05:00  194.138915  197.034732  193.900095  196.994934
#
#      Volume  Dividends  Stock Splits
# 0  47477700        0.0           0.0
# 1  53377300        0.0           0.0
# 2  60943700        0.0           0.0
# 3  52696900        0.0           0.0
# 4  70404200        0.0           0.0

# %%
df_google.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2023-12-07 00:00:00-05:00  136.265366  139.657030  135.896262  138.110825
# 1  2023-12-08 00:00:00-05:00  135.327672  137.651966  135.237896  136.305267
# 2  2023-12-11 00:00:00-05:00  133.492177  134.459786  132.564447  134.370010
# 3  2023-12-12 00:00:00-05:00  132.943518  134.210396  132.504594  133.312607
# 4  2023-12-13 00:00:00-05:00  134.215388  134.449813  132.624294  133.641800
#
#      Volume  Dividends  Stock Splits
# 0  38419400        0.0           0.0
# 1  22990900        0.0           0.0
# 2  24502900        0.0           0.0
# 3  26584000        0.0           0.0
# 4  25414500        0.0           0.0

# %%
df_amazon.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2023-12-07 00:00:00-05:00  146.149994  147.919998  145.339996  146.880005
# 1  2023-12-08 00:00:00-05:00  145.479996  147.839996  145.399994  147.419998
# 2  2023-12-11 00:00:00-05:00  145.660004  146.190002  143.639999  145.889999
# 3  2023-12-12 00:00:00-05:00  145.520004  147.500000  145.300003  147.479996
# 4  2023-12-13 00:00:00-05:00  148.119995  149.460007  146.820007  148.839996
#
#      Volume  Dividends  Stock Splits
# 0  52352800        0.0           0.0
# 1  41858000        0.0           0.0
# 2  50907300        0.0           0.0
# 3  44944300        0.0           0.0
# 4  52766200        0.0           0.0

# %%
df_apple.rename(columns=lambda x:x.strip().lower().replace(' ','_'),inplace=True)

# %%
df_amazon.rename(columns=lambda x:x.strip().lower().replace(' ','_'),inplace=True)
df_google.rename(columns=lambda x:x.strip().lower().replace(' ','_'),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          252 non-null    object
#  1   Open          252 non-null    float64
#  2   High          252 non-null    float64
#  3   Low           252 non-null    float64
#  4   Close         252 non-null    float64
#  5   Volume        252 non-null    int64
#  6   Dividends     252 non-null    float64
#  7   Stock Splits  252 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 15.9+ KB

# %%
df_apple.nunique()
# Out:
# date            252
# open            251
# high            251
# low             252
# close           249
# volume          252
# dividends         3
# stock_splits      1
# dtype: int64

# %%
df_apple.drop(columns='stock_splits',inplace=True)

# %%
df_google.drop(columns='stock_splits',inplace=True)
sf_amazon .drop(columns='stock_splits',inplace=True)

# %%
df_apple.isna().sum(),df_google.isna().sum(),df_amazon.isna().sum()
# Out:
# (date         0
#  open         0
#  high         0
#  low          0
#  close        0
#  volume       0
#  dividends    0
#  dtype: int64,
#  date         0
#  open         0
#  high         0
#  low          0
#  close        0
#  volume       0
#  dividends    0
#  dtype: int64,
#  date         0
#  open         0
#  high         0
#  low          0
#  close        0
#  volume       0
#  dividends    0
#  dtype: int64)

# %%
df_apple.describe().T
# Out:
#            count          mean           std           min           25%  \
# open       252.0  2.029291e+02  2.291698e+01  1.647539e+02  1.829896e+02
# high       252.0  2.047799e+02  2.313800e+01  1.658001e+02  1.845978e+02
# low        252.0  2.012167e+02  2.266558e+01  1.634884e+02  1.816829e+02
# close      252.0  2.031189e+02  2.301487e+01  1.644051e+02  1.834525e+02
# volume     252.0  5.750956e+07  3.047193e+07  2.811130e+07  4.209502e+07
# dividends  252.0  3.928571e-03  3.099998e-02  0.000000e+00  0.000000e+00
#
#                     50%           75%           max
# open       1.965116e+02  2.250050e+02  2.439900e+02
# high       1.980398e+02  2.270327e+02  2.446300e+02
# low        1.950694e+02  2.231459e+02  2.421300e+02
# close      1.970696e+02  2.256467e+02  2.430400e+02
# volume     5.013555e+07  6.372982e+07  3.186799e+08
# dividends  0.000000e+00  0.000000e+00  2.500000e-01

# %%
df_apple['tinker']='AAPL'

# %%
df_apple.head()
# Out:
#                         date        open        high         low       close  \
# 0  2023-12-07 00:00:00-05:00  192.686027  194.049343  192.646214  193.322906
# 1  2023-12-08 00:00:00-05:00  193.253227  195.034508  192.725812  194.755875
# 2  2023-12-11 00:00:00-05:00  192.168554  192.546706  190.486791  192.238205
# 3  2023-12-12 00:00:00-05:00  192.138714  193.770718  190.785344  193.760773
# 4  2023-12-13 00:00:00-05:00  194.138915  197.034732  193.900095  196.994934
#
#      volume  dividends tinker
# 0  47477700        0.0   AAPL
# 1  53377300        0.0   AAPL
# 2  60943700        0.0   AAPL
# 3  52696900        0.0   AAPL
# 4  70404200        0.0   AAPL

# %%
df_amazon['tinker']='AMZN'
df_google['tinker']='GOOG'

# %%
result=pd.concat([df_apple,df_amazon,df_google],ignore_index=True)

# %%
result.head()
# Out:
#                         date        open        high         low       close  \
# 0  2023-12-07 00:00:00-05:00  192.686027  194.049343  192.646214  193.322906
# 1  2023-12-08 00:00:00-05:00  193.253227  195.034508  192.725812  194.755875
# 2  2023-12-11 00:00:00-05:00  192.168554  192.546706  190.486791  192.238205
# 3  2023-12-12 00:00:00-05:00  192.138714  193.770718  190.785344  193.760773
# 4  2023-12-13 00:00:00-05:00  194.138915  197.034732  193.900095  196.994934
#
#      volume  dividends tinker
# 0  47477700        0.0   AAPL
# 1  53377300        0.0   AAPL
# 2  60943700        0.0   AAPL
# 3  52696900        0.0   AAPL
# 4  70404200        0.0   AAPL

# %%
result['tinker'].value_counts()
# Out:
# tinker
# AAPL    252
# AMZN    252
# GOOG    252
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
for i in result['tinker'].unique():
    df_i=result[result['tinker']==i]
    plt.plot(df_i['date'],df_i['close'],label=i)
plt.ylabel('close price')
plt.legend()
plt.show()

# %%
result['close'].loc[result['tinker']=='AMZN'].max()-result['close'].loc[result['tinker']=='AMZN'].min()
# Out:
# 82.45999145507812

# %%
result['close'].loc[result['tinker']=='AAPL'].max()-result['close'].loc[result['tinker']=='AAPL'].min()
# Out:
# 78.63487243652344

# %%
result['close'].loc[result['tinker']=='GOOG'].max()-result['close'].loc[result['tinker']=='GOOG'].min()
# Out:
# 60.17147827148435

# %%
plt.figure(figsize=(10,6))
for i in result['tinker'].unique():
    df_i=result[result['tinker']==i]
    plt.plot(df_i['date'],df_i['high'],label=i)
plt.xlabel('2023')
plt.ylabel('close price')
plt.legend()
plt.show()

# %%
result['open'].loc[result['tinker']=='AMZN'].max()-result['open'].loc[result['tinker']=='AMZN'].min()
# Out:
# 76.05999755859375

# %%
df_apple.loc[:,['open','close','high']].pct_change().plot()
# Out:
# <Axes: >

# %%
result['close'].nunique()
# Out:
# 740

# %%
result.describe(include='all').T
# Out:
#            count unique                        top freq             mean  \
# date         756    252  2023-12-07 00:00:00-05:00    3              NaN
# open       756.0    NaN                        NaN  NaN       181.404178
# high       756.0    NaN                        NaN  NaN       183.171271
# low        756.0    NaN                        NaN  NaN       179.697913
# close      756.0    NaN                        NaN  NaN       181.516814
# volume     756.0    NaN                        NaN  NaN  39704410.582011
# dividends  756.0    NaN                        NaN  NaN         0.001839
# tinker       756      3                       AAPL  252              NaN
#
#                       std         min         25%         50%         75%  \
# date                  NaN         NaN         NaN         NaN         NaN
# open             24.88798  132.414825  166.382758  179.815002  192.515449
# high            25.072515  133.691688  168.000355  181.379997  193.845391
# ...

# %%
plt.figure(figsize=(10,6))
df_a=result.loc[result['tinker']=='AAPL']
plt.plot(df_a['date'],df_a['close'])
plt.xlabel('2023')
plt.ylabel('close price')
plt.show()

# %%
df_apple.tail()
# Out:
#                           date        open        high         low  \
# 247  2024-12-02 00:00:00-05:00  237.270004  240.789993  237.160004
# 248  2024-12-03 00:00:00-05:00  239.809998  242.759995  238.899994
# 249  2024-12-04 00:00:00-05:00  242.869995  244.110001  241.250000
# 250  2024-12-05 00:00:00-05:00  243.990005  244.539993  242.130005
# 251  2024-12-06 00:00:00-05:00  242.910004  244.630005  242.080002
#
#           close    volume  dividends tinker
# 247  239.589996  48137100        0.0   AAPL
# 248  242.649994  38861000        0.0   AAPL
# 249  243.009995  44383900        0.0   AAPL
# 250  243.039993  40033900        0.0   AAPL
# 251  242.839996  36852100        0.0   AAPL

# %%
df_n=pd.read_csv('nvidia_stock_data.csv')

# %%
df_n
# Out:
#                           Date        Open        High         Low  \
# 0    2023-12-07 00:00:00-05:00   45.687048   46.615786   45.591075
# 1    2023-12-08 00:00:00-05:00   46.581794   47.727469   46.536804
# 2    2023-12-11 00:00:00-05:00   47.477542   47.517528   45.817014
# 3    2023-12-12 00:00:00-05:00   46.032947   47.652486   46.032947
# 4    2023-12-13 00:00:00-05:00   47.615506   48.580232   47.594512
# ..                         ...         ...         ...         ...
# 247  2024-12-02 00:00:00-05:00  138.820436  140.440320  137.810511
# 248  2024-12-03 00:00:00-05:00  138.250473  140.530315  137.940497
# 249  2024-12-04 00:00:00-05:00  141.990222  145.779954  140.280333
# 250  2024-12-05 00:00:00-05:00  145.110001  146.539993  143.949997
# 251  2024-12-06 00:00:00-05:00  144.600006  145.699997  141.309998
#
#           Close     Volume  Dividends  Stock Splits
# 0     46.582794  350823000       0.00           0.0
# 1     47.492535  359224000       0.00           0.0
# ...

# %%
result['close'].loc[result['tinker']=='AAPL'].plot(title='apple closing price')
# Out:
# <Axes: title={'center': 'apple closing price'}>

# %%
nvidia_df=pd.read_csv('nvidia_stock_data1.csv')

# %%
nvidia_df['Close'].plot()
# Out:
# <Axes: >

# %%
nvidia_df.shape
# Out:
# (2517, 8)

# %%
nvidia_df['Close'].max()
# Out:
# 148.8697509765625

# %%
df_apple.head()
# Out:
#                         date        open        high         low       close  \
# 0  2023-12-07 00:00:00-05:00  192.686027  194.049343  192.646214  193.322906
# 1  2023-12-08 00:00:00-05:00  193.253227  195.034508  192.725812  194.755875
# 2  2023-12-11 00:00:00-05:00  192.168554  192.546706  190.486791  192.238205
# 3  2023-12-12 00:00:00-05:00  192.138714  193.770718  190.785344  193.760773
# 4  2023-12-13 00:00:00-05:00  194.138915  197.034732  193.900095  196.994934
#
#      volume  dividends tinker
# 0  47477700        0.0   AAPL
# 1  53377300        0.0   AAPL
# 2  60943700        0.0   AAPL
# 3  52696900        0.0   AAPL
# 4  70404200        0.0   AAPL

# %%
df_apple['close'].plot()
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
df_apple.head()
# Out:
#                         date        open        high         low       close  \
# 0  2023-12-07 00:00:00-05:00  192.686027  194.049343  192.646214  193.322906
# 1  2023-12-08 00:00:00-05:00  193.253227  195.034508  192.725812  194.755875
# 2  2023-12-11 00:00:00-05:00  192.168554  192.546706  190.486791  192.238205
# 3  2023-12-12 00:00:00-05:00  192.138714  193.770718  190.785344  193.760773
# 4  2023-12-13 00:00:00-05:00  194.138915  197.034732  193.900095  196.994934
#
#      volume  dividends tinker
# 0  47477700        0.0   AAPL
# 1  53377300        0.0   AAPL
# 2  60943700        0.0   AAPL
# 3  52696900        0.0   AAPL
# 4  70404200        0.0   AAPL

# %%
plt.plot(df_apple['date'],df_apple['close'])
